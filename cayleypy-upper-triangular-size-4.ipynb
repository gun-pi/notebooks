# %%
# !pip install git+https://github.com/cayleypy/cayleypy
# !pip install git+https://github.com/gun-pi/notebooks

# %%
import numpy as np

from cayleypy_upper_triangular_utils import generate_basis_matrix, print_graph_visualization_and_spectrum, \
    calculate_growth_and_diameter

# %%
def generate_matrices(k: int) -> list[list[np.ndarray]]:
    """
    Generate a list of matrices M_{ij} = Id + E_{ij}, where j = i + 1.
    """
    assert k > 2
    matrices = []
    identity = np.eye(k, dtype=int)

    for i in range(k - 1):
        j = i + 1
        M_ij = identity + generate_basis_matrix(k, i, j)
        matrices.append(M_ij.tolist())

    return matrices

# %% [markdown]
# ### Growth calculation with matrix size = 4

# %%
matrix_size = 4
generators_mxs = generate_matrices(matrix_size)

# %% [markdown]
# #### Print graph visualization and spectrum for small graphs

# %%
modulo = 2
print_graph_visualization_and_spectrum(modulo, generators_mxs, include_inverses=True)
print_graph_visualization_and_spectrum(modulo, generators_mxs, include_inverses=False)

modulo = 3
print_graph_visualization_and_spectrum(modulo, generators_mxs, include_inverses=True)
print_graph_visualization_and_spectrum(modulo, generators_mxs, include_inverses=False)
# Out:
# Calculating and printing graph visualization and spectrum.
# Modulo = 2, WITH inverted generators.
# Calculating and printing graph visualization and spectrum.
# Modulo = 2, WITHOUT inverted generators.
# Calculating and printing graph visualization and spectrum.
# Modulo = 3, WITH inverted generators.
# Calculating and printing graph visualization and spectrum.
# Modulo = 3, WITHOUT inverted generators.

# %% [markdown]
# #### Growth calculation for generators for modulos in range [2, 22]

# %%
modulo_max = 22

# %%
calculate_growth_and_diameter(modulo_max, generators_mxs, include_inverses=True)
calculate_growth_and_diameter(modulo_max, generators_mxs, include_inverses=False)
# Out:
# Calculating graph growth and diameter WITH inverted generators.
#
# [modulo = 2] diameter = 8 | growth = [1, 3, 5, 8, 11, 13, 13, 8, 2]
# [modulo = 3] diameter = 8 | growth = [1, 6, 20, 56, 116, 208, 268, 52, 2]
# [modulo = 4] diameter = 10 | growth = [1, 6, 23, 84, 233, 560, 1111, 1310, 671, 88, 9]
# [modulo = 5] diameter = 10 | growth = [1, 6, 26, 104, 368, 1032, 2792, 6004, 4858, 428, 6]
# [modulo = 6] diameter = 13 | growth = [1, 6, 26, 107, 388, 1192, 3397, 8571, 14981, 13052, 4506, 396, 29, 4]
# [modulo = 7] diameter = 12 | growth = [1, 6, 26, 110, 408, 1400, 4220, 12036, 29830, 46784, 21562, 1232, 34]
# [modulo = 8] diameter = 14 | growth = [1, 6, 26, 110, 411, 1420, 4460, 13032, 33880, 69286, 84109, 46804, 8143, 414, 42]
# [modulo = 9] diameter = 13 | growth = [1, 6, 26, 110, 414, 1440, 4732, 14172, 39326, 95912, 173398, 159668, 41712, 524]
# Calculating graph growth and diameter WITHOUT inverted generators.
#
# [modulo = 2] diameter = 8 | growth = [1, 3, 5, 8, 11, 13, 13, 8, 2]
# [modulo = 3] diameter = 12 | growth = [1, 3, 8, 18, 36, 63, 103, 157, 167, 120, 47, 5, 1]
# [modulo = 4] diameter = 16 | growth = [1, 3, 8, 21, 48, 99, 191, 352, 594, 792, 805, 648, 380, 130, 20, 3, 1]
# [modulo = 5] diameter = 17 | growth = [1, 3, 8, 21, 53, 117, 244, 490, 946, 1662, 2375, 2706, 2622, 2158, 1410, 632, 172, 5]
# [modulo = 6] diameter = 21 | growth = [1, 3, 8, 21, 53, 124, 268, 563, 1141, 2180, 3697, 5286, 6414, 6839, 6577, 5571, 4026, 2366, 1093, 371, 50, 4]
# [modulo = 7] diameter = 23 | growth = [1, 3, 8, 21, 53, 128, 285, 612, 1288, 2606, 4873, 7906, 10983, 13482, 14815, 15094, 14186, 11913, 8848, 5696, 3040, 1379, 422, 7]
# [modulo = 8] diameter = 26 | growth = [1, 3, 8, 21, 53, 128, 291, 635, 1357, 2818, 5520, 9692, 14729, 19961, 24628, 27754, 29280, 29211, 27168, 23055, 17986, 12679, 7849, 4379, 2130, 736, 72]
# [modulo = 9] diameter = 29 | growth = [1, 3, 8, 21, 53, 128, 297, 655, 1415, 2989, 6040, 11267, 18493, 26470, 34684, 42377, 48301, 51801, 53226, 52114, 47757, 40535, 32526, 24237, 16375, 10093, 5833, 2833, 892, 17]
